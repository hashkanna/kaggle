# %%
import pandas as pd
import os

os.chdir('/Users/kanna/Sandbox/kaggle/walmart')
train = pd.read_csv('walmart_train_full.csv')
train.keys()
# Out:
# Index([Store, Dept, Date, Weekly_Sales, IsHoliday, week_num, Id, Temperature, Fuel_Price, MarkDown1, MarkDown2, MarkDown3, MarkDown4, MarkDown5, CPI, Unemployment, week_of_year], dtype=object)

# %%
train.head(5)
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday  week_num              Id  \
# 0      1     1  2010-02-05      24924.50          0         0  1_1_2010-02-05
# 1      1     1  2010-02-12      46039.49          0         1  1_1_2010-02-12
# 2      1     1  2010-02-19      41595.55          0         2  1_1_2010-02-19
# 3      1     1  2010-02-26      19403.54          0         3  1_1_2010-02-26
# 4      1     1  2010-03-05      21827.90          0         4  1_1_2010-03-05
#
#    Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5  \
# 0        42.31       2.572        NaN        NaN        NaN        NaN        NaN
# 1        38.51       2.548        NaN        NaN        NaN        NaN        NaN
# 2        39.93       2.514        NaN        NaN        NaN        NaN        NaN
# 3        46.63       2.561        NaN        NaN        NaN        NaN        NaN
# 4        46.50       2.625        NaN        NaN        NaN        NaN        NaN
#
# ...

# %%
train[['Store', 'Dept', 'week_of_year', 'Weekly_Sales']].head(5)
# Out:
#    Store  Dept  week_of_year  Weekly_Sales
# 0      1     1             5      24924.50
# 1      1     1             6      46039.49
# 2      1     1             7      41595.55
# 3      1     1             8      19403.54
# 4      1     1             9      21827.90

# %%
plt.hist(train['Store'], 45)
# Out:
# (array([10244, 10238,  9036, 10272,  8999, 10211,  9762,  9895,  8867,
#        10315, 10062,  9705, 10474, 10040,  9901,  9443,  9864,  9859,
#        10148, 10214,  9582,  9688, 10050, 10228,  9804,  9854, 10225,
#        10113,  9455,  7156, 10142, 10202,  6487, 10224,  9528,  6222,
#         7206,  7362,  9878, 10017, 10088,  6953,  6751,  7169,  9637]),
#  array([  1.        ,   1.97777778,   2.95555556,   3.93333333,
#          4.91111111,   5.88888889,   6.86666667,   7.84444444,
#          8.82222222,   9.8       ,  10.77777778,  11.75555556,
#         12.73333333,  13.71111111,  14.68888889,  15.66666667,
#         16.64444444,  17.62222222,  18.6       ,  19.57777778,
#         20.55555556,  21.53333333,  22.51111111,  23.48888889,
#         24.46666667,  25.44444444,  26.42222222,  27.4       ,
#         28.37777778,  29.35555556,  30.33333333,  31.31111111,
#         32.28888889,  33.26666667,  34.24444444,  35.22222222,
# ...

# %%
plt.scatter(train['Store'], train['Weekly_Sales'])

# %%
plt.scatter(train['week_of_year'], train['Weekly_Sales'])

# %%
train_X = train[['Store', 'Dept', 'week_of_year']]
train_y = train[['Weekly_Sales']]

from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(train_X, train_y)

test = pd.read_csv('walmart_test_full.csv')
test_X = test[['Store', 'Dept', 'week_of_year']]
lin_reg_predicted = lin_reg.predict(test_X)
lin_reg_predicted
# Out:
# array([[ 15294.66078672],
#        [ 15339.00599253],
#        [ 15383.35119833],
#        ...,
#        [ 18489.71707649],
#        [ 18534.06228229],
#        [ 18578.40748809]])

# %%
from sklearn.ensemble import GradientBoostingRegressor
grad_boost_reg = GradientBoostingRegressor()
grad_boost_reg.fit(train_X, train_y)
grad_boost_reg_predicted = grad_boost_reg.predict(test_X)
pd.Series(grad_boost_reg_predicted)
# Out:
# 0     25863.408712
# 1     25863.408712
# 2     25863.408712
# 3     30924.016843
# 4     30924.016843
# 5     32457.318118
# 6     38849.190550
# 7     41128.785079
# 8     31497.111383
# 9     24917.454742
# 10    24917.454742
# 11    24917.454742
# 12    24917.454742
# 13    25231.167727
# 14    25231.167727
# ...
# 115049   -148.534931
# 115050   -148.534931
# 115051   -148.534931
# 115052   -148.534931
# 115053   -148.534931
# 115054   -148.534931
# 115055   -148.534931
# 115056   -148.534931
# 115057   -148.534931
# 115058   -148.534931
# 115059   -148.534931
# 115060   -148.534931
# 115061   -148.534931
# 115062   -148.534931
# 115063   -148.534931
# Length: 115064

# %%
test['Weekly_Sales'] = pd.Series(grad_boost_reg_predicted)
test.to_csv('result5.csv', cols=['Id', 'Weekly_Sales'], index=False)

# %%
plt.scatter(train[['Fuel_Price']], train[['Weekly_Sales']])

# %%
from sklearn.preprocessing import OneHotEncoder
train_X = train[['Store']]
dummy_stores = pd.get_dummies(train['Store'], prefix='Store')
print dummy_stores.head()
dummy_stores.ix[:, 'Store_1':].head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 0 to 4
# Data columns:
# Store_1     5  non-null values
# Store_2     5  non-null values
# Store_3     5  non-null values
# Store_4     5  non-null values
# Store_5     5  non-null values
# Store_6     5  non-null values
# Store_7     5  non-null values
# Store_8     5  non-null values
# Store_9     5  non-null values
# Store_10    5  non-null values
# Store_11    5  non-null values
# Store_12    5  non-null values
# Store_13    5  non-null values
# Store_14    5  non-null values
# Store_15    5  non-null values
# Store_16    5  non-null values
# Store_17    5  non-null values
# Store_18    5  non-null values
# Store_19    5  non-null values
# Store_20    5  non-null values
# Store_21    5  non-null values
# Store_22    5  non-null values
# Store_23    5  non-null values
# Store_24    5  non-null values
# Store_25    5  non-null values
# Store_26    5  non-null values
# Store_27    5  non-null values
# ...
