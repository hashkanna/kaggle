# %%
import pandas as pd
import os

os.chdir('/Users/kanna/Sandbox/kaggle/allstate_purchase/')
train = pd.read_csv('train.csv')
train_final = train[train['record_type']==1]
test_final = pd.read_csv('test_final.csv')
X_train = train_final[['day', 'time', 'state', 'location', 'group_size', 'homeowner', 'car_age', 'car_value', 'risk_factor', 'age_oldest', 'age_youngest', 'married_couple', 'duration_previous']]
X_train = X_train.fillna(X_train.median())
A_train = train_final['A']
B_train = train_final['B']
C_train = train_final['C']
D_train = train_final['D']
E_train = train_final['E']
F_train = train_final['F']
G_train = train_final['G']
X_test = test_final[['day', 'time', 'state', 'location', 'group_size', 'homeowner', 'car_age', 'car_value', 'risk_factor', 'age_oldest', 'age_youngest', 'married_couple', 'duration_previous']]
X_train.head()
# Out:
#     day   time state  location  group_size  homeowner  car_age car_value  \
# 8     0  12:07    IN     10001           2          0        2         g
# 14    3  09:09    NY     10006           1          0       10         e
# 22    4  14:26    PA     10008           1          0       11         c
# 26    4  09:31    WV     10014           2          1        3         d
# 32    1  17:50    MO     10015           1          0        5         d
#
#     risk_factor  age_oldest  age_youngest  married_couple  duration_previous
# 8             3          46            42               1                  2
# 14            4          28            28               0                 13
# 22            3          43            43               0                  4
# 26            3          62            60               1                  3
# 32            3          32            28               1                  2
#
# [5 rows x 13 columns]

# %%
from sklearn.svm import LinearSVC
svm_classifier = LinearSVC().fit(X_train, A_train)
A_svm_predicted = svm_classifier.predict(
